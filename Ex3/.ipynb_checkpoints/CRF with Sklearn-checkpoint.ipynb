# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

nltk.download('conll2002')
# Out:
# [nltk_data] Downloading package conll2002 to
# [nltk_data]     C:\Users\Jan\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2002 is already up-to-date!
# True

# %%
print(nltk.corpus.conll2002.fileids())

train_sents = list(nltk.corpus.conll2002.iob_sents('esp.train'))
test_sents = list(nltk.corpus.conll2002.iob_sents('esp.testb'))

test_sents[0]
# Out:
# ['esp.testa', 'esp.testb', 'esp.train', 'ned.testa', 'ned.testb', 'ned.train']
# [('La', 'DA', 'B-LOC'),
#  ('Coruña', 'NC', 'I-LOC'),
#  (',', 'Fc', 'O'),
#  ('23', 'Z', 'O'),
#  ('may', 'NC', 'O'),
#  ('(', 'Fpa', 'O'),
#  ('EFECOM', 'NP', 'B-ORG'),
#  (')', 'Fpt', 'O'),
#  ('.', 'Fp', 'O')]

# %%
def load_data(fname):
    idata = open(fname, 'rt', encoding='utf-8').readlines()
    sentences = []
    sentence = []
    for line in idata:
        if line == '\n':
            sentences.append(sentence)
            sentence = []
            continue
        if line.startswith('#'):
            continue
        word = line.replace('\n', '').split('\t')[1:]
        sentence.append(tuple(word))
    return sentences
        
    
train_sents = load_data('GermEval2014_complete_data/NER-de-train.tsv')
valid_sents = load_data('GermEval2014_complete_data/NER-de-dev.tsv')
test_sents = load_data('GermEval2014_complete_data/NER-de-test.tsv')

test_sents
# Out:
# [[('1951', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('1953', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('nördliche', 'O', 'O'),
#   ('Teil', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('Jugendburg', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Kolpingwerkes', 'B-OTH', 'O'),
#   ('gebaut', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Da', 'O', 'O'),
#   ('Muck', 'B-PER', 'O'),
#   ('das', 'O', 'O'),
#   ('Kriegsschreiben', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('überbracht', 'O', 'O'),
#   ('hat', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('Retter', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Landes', 'O', 'O'),
#   ('ausgezeichnet', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('soll', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Schatzmeister', 'O', 'O'),
#   ('ernannt', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Mit', 'O', 'O'),
#   ('1.', 'O', 'O'),
#   ('Jänner', 'O', 'O'),
#   ('2007', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('Robert', 'B-PER', 'O'),
#   ('Schörgenhofer', 'I-PER', 'O'),
#   (',', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('Nachfolger', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('ausgeschiedenen', 'O', 'O'),
#   ('Dietmar', 'B-PER', 'O'),
#   ('Drabek', 'I-PER', 'O'),
#   (',', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Kaderliste', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('FIFA-Schiedsrichter', 'B-ORGpart', 'O'),
#   ('aufgenommen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('These', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Schlatter', 'B-PER', 'O'),
#   ('sei', 'O', 'O'),
#   ('Antisemit', 'O', 'O'),
#   ('gewesen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('seither', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('theologischen', 'O', 'O'),
#   ('Fachliteratur', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('mehr', 'O', 'O'),
#   ('vertreten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('"', 'O', 'O'),
#   ('Lehmbruck', 'B-OTH', 'B-PER'),
#   ('-', 'I-OTH', 'O'),
#   ('Beuys', 'I-OTH', 'B-PER'),
#   ('.Zeichnungen', 'I-OTH', 'O'),
#   ('"', 'O', 'O'),
#   ('lautet', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Titel', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('gerade', 'O', 'O'),
#   ('eröffneten', 'O', 'O'),
#   ('Ausstellung', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Kuratorin', 'O', 'O'),
#   ('Dr', 'O', 'O'),
#   ('.', 'O', 'O'),
#   ('Marion', 'B-PER', 'O'),
#   ('Bornscheuer', 'I-PER', 'O'),
#   ('bis', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('11.', 'O', 'O'),
#   ('Januar', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Lehmbruck-Museum', 'B-ORG', 'O'),
#   ('präsentiert', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Videohoster', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Vertreter', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Autoren', 'O', 'O'),
#   ('schieben', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('gegenseitig', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('schwarzen', 'O', 'O'),
#   ('Peter', 'B-PER', 'O'),
#   ('zu', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Kanzel', 'O', 'O'),
#   ('befindet', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Südseite', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Saals', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Zuletzt', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('Wolfram', 'B-PER', 'O'),
#   ('Graf-Rudolf', 'I-PER', 'O'),
#   (',', 'O', 'O'),
#   ('Chef', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Zoos', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Aachen', 'B-LOC', 'O'),
#   ('.', 'O', 'O')],
#  [('Nach', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Symptomen', 'O', 'O'),
#   ('lassen', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('beiden', 'O', 'O'),
#   ('Krankheiten', 'O', 'O'),
#   ('-', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('normale', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Influenza', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Schweinegrippe', 'O', 'O'),
#   ('-', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('unterscheiden', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Politisch', 'O', 'O'),
#   ('interessiert', 'O', 'O'),
#   ('ging', 'O', 'O'),
#   ('Antommarchi', 'B-PER', 'O'),
#   ('nach', 'O', 'O'),
#   ('Polen', 'B-LOC', 'O'),
#   ('und', 'O', 'O'),
#   ('übernahm', 'O', 'O'),
#   ('dort', 'O', 'O'),
#   ('1830', 'O', 'O'),
#   ('während', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Novemberaufstandes', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Warschau', 'B-LOC', 'O'),
#   ('die', 'O', 'O'),
#   ('Leitung', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('ärztlichen', 'O', 'O'),
#   ('Anstalten', 'O', 'O'),
#   (';', 'O', 'O'),
#   ('kehrte', 'O', 'O'),
#   ('jedoch', 'O', 'O'),
#   ('bald', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('Paris', 'B-LOC', 'O'),
#   ('zurück', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Am', 'O', 'O'),
#   ('20.', 'O', 'O'),
#   ('Januar', 'O', 'O'),
#   ('1839', 'O', 'O'),
#   ('gelang', 'O', 'O'),
#   ('Manuel', 'B-PER', 'O'),
#   ('Bulnes', 'I-PER', 'O'),
#   ('bei', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Belagerung', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Yungay', 'B-LOC', 'O'),
#   ('der', 'O', 'O'),
#   ('entscheidende', 'O', 'O'),
#   ('Sieg', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('Auto', 'O', 'O'),
#   ('geriet', 'O', 'O'),
#   ('ins', 'O', 'O'),
#   ('Schleudern', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('kam', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('rechts', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Fahrbahn', 'O', 'O'),
#   ('ab', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('prallte', 'O', 'O'),
#   ('gegen', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('Baum', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Dramaturgie', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Partie', 'O', 'O'),
#   ('hielt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('was', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('Fußballfans', 'O', 'O'),
#   ('weltweit', 'O', 'O'),
#   ('erträumt', 'O', 'O'),
#   ('hatten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('DEG-Torhüter', 'B-ORGpart', 'O'),
#   ('Jamie', 'B-PER', 'O'),
#   ('Storr', 'I-PER', 'O'),
#   ('(', 'O', 'O'),
#   ('Mitte', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('kann', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Schuss', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('1:0', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('parieren', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Im', 'O', 'O'),
#   ('Bereich', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('strukturierten', 'O', 'O'),
#   ('Produkte', 'O', 'O'),
#   ('beobachten', 'O', 'O'),
#   ('wir', 'O', 'O'),
#   ('derzeit', 'O', 'O'),
#   ('sogar', 'O', 'O'),
#   ('Rekordvolumen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('monatelange', 'O', 'O'),
#   ('Führungskrise', 'O', 'O'),
#   ('beim', 'O', 'O'),
#   ('europäischen', 'B-LOCderiv', 'O'),
#   ('Luft-und', 'O', 'O'),
#   ('Raumfahrtkonzern', 'O', 'O'),
#   ('EADS', 'B-ORG', 'O'),
#   ('ist', 'O', 'O'),
#   ('beigelegt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Denn', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Ordnung', 'O', 'O'),
#   ('was', 'O', 'O'),
#   ('du', 'O', 'O'),
#   ('heute', 'O', 'O'),
#   ('hier', 'O', 'O'),
#   ('gemacht', 'O', 'O'),
#   ('hast', 'O', 'O'),
#   ('!', 'O', 'O')],
#  [('Heute', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('durch', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('roten', 'O', 'O'),
#   ('Ziegelstreifen', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Verlauf', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Turm', 'O', 'O'),
#   ('anschließenden', 'O', 'O'),
#   ('nordwestlichen', 'O', 'O'),
#   ('Mauerrings', 'O', 'O'),
#   ('gekennzeichnet', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('während', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('südwestliche', 'O', 'O'),
#   ('Mauerring', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Gelände', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('ehemaligen', 'O', 'O'),
#   ('Franziskanerklosters', 'O', 'O'),
#   ('St', 'B-LOC', 'O'),
#   ('.', 'I-LOC', 'O'),
#   ('Johannis', 'I-LOC', 'B-PER'),
#   ('noch', 'O', 'O'),
#   ('intakt', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Verwaltungsdienst', 'O', 'O'),
#   ('Zumeist', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Hintergrund', 'O', 'O'),
#   ('handelnd', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('allen', 'O', 'O'),
#   ('Polizeien', 'O', 'O'),
#   ('tätige', 'O', 'O'),
#   ('Verwaltungsdienst', 'O', 'O'),
#   ('selten', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Uniform', 'O', 'O'),
#   ('anzutreffen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Mit', 'O', 'O'),
#   ('Herzog', 'O', 'O'),
#   ('Przemysław', 'B-PER', 'O'),
#   ('II.', 'I-PER', 'O'),
#   ('von', 'O', 'O'),
#   ('Großpolen', 'B-LOC', 'O'),
#   ('schloss', 'O', 'O'),
#   ('Mestwin', 'B-PER', 'O'),
#   ('am', 'O', 'O'),
#   ('15.', 'O', 'O'),
#   ('Februar', 'O', 'O'),
#   ('1282', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Vertrag', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Kempen', 'B-LOC', 'O'),
#   ('eine', 'O', 'O'),
#   ('„', 'O', 'O'),
#   ('donatio', 'O', 'O'),
#   ('inter', 'O', 'O'),
#   ('vivos', 'O', 'O'),
#   ('“', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Geschenk', 'O', 'O'),
#   ('unter', 'O', 'O'),
#   ('Lebenden', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('vermachte', 'O', 'O'),
#   ('ihm', 'O', 'O'),
#   ('sein', 'O', 'O'),
#   ('Herzogtum', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Philosophisch', 'O', 'O'),
#   ('strittig', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('ob', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Raum', 'O', 'O'),
#   ('„', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('“', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('unabhängig', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Wahrnehmung', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Vorstellung', 'O', 'O'),
#   ('existiert', 'O', 'O'),
#   ('oder', 'O', 'O'),
#   ('lediglich', 'O', 'O'),
#   ('eine', 'O', 'O'),
#   ('Anschauungsform', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('wahrnehmenden', 'O', 'O'),
#   ('Subjekts', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('London', 'B-ORG', 'B-LOC'),
#   ('Telegram', 'I-ORG', 'O'),
#   ('vom', 'O', 'O'),
#   ('21.', 'O', 'O'),
#   ('Januar', 'O', 'O'),
#   ('1914', 'O', 'O'),
#   ('berichtete', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('Karl', 'B-PER', 'O'),
#   ('Richter', 'I-PER', 'O'),
#   ('wegen', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Diebstahls', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('belastenden', 'O', 'O'),
#   ('Papiere', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('versuchten', 'O', 'O'),
#   ('Erpressung', 'O', 'O'),
#   ('seines', 'O', 'O'),
#   ('Arbeitgebers', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Deutschland', 'B-LOC', 'O'),
#   ('zu', 'O', 'O'),
#   ('2', 'O', 'O'),
#   ('Jahren', 'O', 'O'),
#   ('Gefängnis', 'O', 'O'),
#   ('verurteilt', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Folge', 'O', 'O'),
#   ('ausgestrahlt', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('älteste', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Schauspielhaus', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('über', 'O', 'O'),
#   ('130', 'O', 'O'),
#   ('Jahre', 'O', 'O'),
#   ('alt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('ursprüngliche', 'O', 'O'),
#   ('Apfeldiätspeise', 'O', 'O'),
#   ('„', 'O', 'O'),
#   ('d', 'B-OTH', 'O'),
#   ('Spys', 'I-OTH', 'O'),
#   ('“', 'O', 'O'),
#   ('Das', 'O', 'O'),
#   ('ursprüngliche', 'O', 'O'),
#   ('Birchermues', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('eine', 'O', 'O'),
#   ('Schweizer', 'B-LOCderiv', 'O'),
#   ('Spezialität', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('um', 'O', 'O'),
#   ('1900', 'O', 'O'),
#   ('Albert', 'B-PER', 'O'),
#   ('Wirz', 'I-PER', 'O'),
#   ('Doktor', 'O', 'O'),
#   ('Birchers', 'B-PER', 'O'),
#   ('neue', 'O', 'O'),
#   ('Weltordnung', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('wichtigste', 'O', 'O'),
#   ('Industriezweig', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Nahrungsmittel-', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Getränkeindustrie', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('gefolgt', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Metall-', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Textilindustrie', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('S', 'B-OTH', 'B-ORG'),
#   ('&', 'I-OTH', 'I-ORG'),
#   ('P', 'I-OTH', 'I-ORG'),
#   ('500', 'I-OTH', 'O'),
#   ('kletterte', 'O', 'O'),
#   ('daneben', 'O', 'O'),
#   ('um', 'O', 'O'),
#   ('0,91', 'O', 'O'),
#   ('Prozent', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('schloss', 'O', 'O'),
#   ('bei', 'O', 'O'),
#   ('927,23', 'O', 'O'),
#   ('Zählern', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Auch', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('dritten', 'O', 'O'),
#   ('Spiel', 'O', 'O'),
#   ('konnte', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('keine', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('beiden', 'O', 'O'),
#   ('Mannschaften', 'O', 'O'),
#   ('absetzen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Wie', 'O', 'O'),
#   ('eine', 'O', 'O'),
#   ('drohende', 'O', 'O'),
#   ('Melodie', 'O', 'O'),
#   ('umschwebte', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Boot', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('kalt', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('gefühllos', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Eigentlich', 'O', 'O'),
#   ('sollte', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('neue', 'O', 'O'),
#   ('Betriebssystem', 'O', 'O'),
#   ('rechtzeitig', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Weihnachtsgeschäft', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Markt', 'O', 'O'),
#   ('kommen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Im', 'O', 'O'),
#   ('Blickpunkt', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Interesses', 'O', 'O'),
#   ('steht', 'O', 'O'),
#   ('vor', 'O', 'O'),
#   ('allem', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('anschließende', 'O', 'O'),
#   ('Presseerklärung', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('Marktteilnehmer', 'O', 'O'),
#   ('Hinweise', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('amerikanische', 'B-LOCderiv', 'O'),
#   ('Geldpolitik', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('kommenden', 'O', 'O'),
#   ('Jahr', 'O', 'O'),
#   ('erhoffen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Mit', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Verpfändung', 'O', 'O'),
#   ('Stolbergs', 'B-LOC', 'O'),
#   ('an', 'O', 'O'),
#   ('Wilhelm', 'B-PER', 'O'),
#   ('von', 'I-PER', 'O'),
#   ('Nesselrode', 'I-PER', 'O'),
#   ('war', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Auflage', 'O', 'O'),
#   ('verbunden', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('eine', 'O', 'O'),
#   ('mögliche', 'O', 'O'),
#   ('neue', 'O', 'O'),
#   ('Burg', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('Offenhaus', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Herzogs', 'O', 'O'),
#   ('von', 'B-PER', 'O'),
#   ('Jülich', 'I-PER', 'B-LOC'),
#   ('zu', 'O', 'O'),
#   ('errichten', 'O', 'O'),
#   ('sei', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Er', 'O', 'O'),
#   ('zeichnete', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('faires', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('interessantes', 'O', 'O'),
#   ('Bild', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Auftrags-', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Arbeitslage', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Mitteldeutschen', 'B-ORG', 'B-LOC'),
#   ('Verlages', 'I-ORG', 'O'),
#   (',', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('Nachwuchsautoren-Haus', 'O', 'O'),
#   ('besonders', 'O', 'O'),
#   ('gefordert', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ein', 'O', 'O'),
#   ('Stadtsiegel', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Wappen', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('seit', 'O', 'O'),
#   ('1297', 'O', 'O'),
#   ('nachweisbar', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Diese', 'O', 'O'),
#   ('bestehen', 'O', 'O'),
#   ('i', 'O', 'O'),
#   ('.', 'O', 'O'),
#   ('d', 'O', 'O'),
#   ('.', 'O', 'O'),
#   ('R', 'O', 'O'),
#   ('.', 'O', 'O'),
#   ('aus', 'O', 'O'),
#   ('einem', 'O', 'O'),
#   ('Lösemittel', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('einem', 'O', 'O'),
#   ('Trägerstoff', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Es', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('weitere', 'O', 'O'),
#   ('Zunahmen', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Belastungen', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('erwarten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Doma', 'B-PER', 'O'),
#   ('ist', 'O', 'O'),
#   ('immer', 'O', 'O'),
#   ('noch', 'O', 'O'),
#   ('sehr', 'O', 'O'),
#   ('aufgewühlt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('Gauner', 'O', 'O'),
#   ('hereingefallen', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Mit', 'O', 'O'),
#   ('922', 'O', 'O'),
#   ('m', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Nordostabdachung', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Belmont', 'B-LOC', 'O'),
#   ('die', 'O', 'O'),
#   ('höchste', 'O', 'O'),
#   ('Erhebung', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Bretonvillers', 'B-LOC', 'O'),
#   ('erreicht', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Kameraarbeit', 'O', 'O'),
#   ('Auch', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Posten', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('Kameramann', 'O', 'O'),
#   ('übernahm', 'O', 'O'),
#   ('Tarantino', 'B-PER', 'O'),
#   ('selbst', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('"', 'O', 'O'),
#   ('Wir', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('vom', 'O', 'O'),
#   ('Ideal', 'O', 'O'),
#   ('eines', 'O', 'O'),
#   ('gebührenfreien', 'O', 'O'),
#   ('Bildungssystems', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Kinderkrippe', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('zur', 'O', 'O'),
#   ('Hochschule', 'O', 'O'),
#   ('weiter', 'O', 'O'),
#   ('entfernt', 'O', 'O'),
#   ('denn', 'O', 'O'),
#   ('je', 'O', 'O'),
#   ('"', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('so', 'O', 'O'),
#   ('Hirsch', 'B-PER', 'O'),
#   ('.', 'O', 'O')],
#  [('Leopold', 'B-ORG', 'B-PER'),
#   ('Stocker', 'I-ORG', 'I-PER'),
#   ('Verlag', 'I-ORG', 'O'),
#   (',', 'O', 'O'),
#   ('Graz', 'B-LOC', 'O'),
#   (',', 'O', 'O'),
#   ('Stuttgart', 'B-LOC', 'O'),
#   ('1994', 'O', 'O'),
#   ('.', 'O', 'O'),
#   ('ISBN', 'O', 'O'),
#   ('3-702-00682-6', 'O', 'O'),
#   ('*', 'O', 'O'),
#   ('1999', 'O', 'O'),
#   (':', 'O', 'O'),
#   ('Erinnerungen', 'B-OTH', 'O'),
#   ('und', 'I-OTH', 'O'),
#   ('Gedanken', 'I-OTH', 'O'),
#   ('.', 'O', 'O')],
#  [('1951', 'O', 'O'),
#   ('fiel', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Startschuss', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('erste', 'O', 'O'),
#   ('Berlinale', 'B-ORG', 'O'),
#   ('.', 'O', 'O')],
#  [('Sie', 'O', 'O'),
#   ('ermuntert', 'O', 'O'),
#   ('ihn', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('mehr', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('sein', 'O', 'O'),
#   ('Gefühl', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('sein', 'O', 'O'),
#   ('Gewissen', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('verlassen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('ohne', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('wissen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('Dexter', 'B-PER', 'O'),
#   ('keines', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('beiden', 'O', 'O'),
#   ('hat', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('1.', 'B-ORG', 'O'),
#   ('FC', 'I-ORG', 'O'),
#   ('Kaiserslautern', 'I-ORG', 'B-LOC'),
#   ('empfängt', 'O', 'O'),
#   ('heute', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Montagspiel', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('2.', 'B-ORG', 'O'),
#   ('Fußball-Bundesliga', 'I-ORG', 'O'),
#   ('den', 'O', 'O'),
#   ('SC', 'B-ORG', 'O'),
#   ('Freiburg', 'I-ORG', 'B-LOC'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Stadt', 'O', 'O'),
#   ('richtete', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Gebäuden', 'O', 'O'),
#   ('eine', 'O', 'O'),
#   ('höhere', 'O', 'O'),
#   ('Knabenschule', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('weshalb', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Gebäude', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Volksmund', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('„', 'O', 'O'),
#   ('Bubenkloster', 'B-OTH', 'O'),
#   ('“', 'O', 'O'),
#   ('genannt', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('verwechseln', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('eigentlichen', 'O', 'O'),
#   ('Klosterschule', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Stiftsbezirk', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ein', 'O', 'O'),
#   ('konsistentes', 'O', 'O'),
#   ('philosophisches', 'O', 'O'),
#   ('oder', 'O', 'O'),
#   ('soziologisches', 'O', 'O'),
#   ('System', 'O', 'O'),
#   ('hinterließ', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('keine', 'O', 'O'),
#   ('Schule', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('1297', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('einem', 'O', 'O'),
#   ('Brief', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Diplomatarium', 'B-OTH', 'O'),
#   ('Norvegicum', 'I-OTH', 'B-LOCderiv'),
#   ('für', 'O', 'O'),
#   ('dieses', 'O', 'O'),
#   ('Jahr', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Erzbischof', 'O', 'O'),
#   ('Jørund', 'B-PER', 'O'),
#   ('in', 'O', 'O'),
#   ('Nidaros', 'B-LOC', 'O'),
#   ('zum', 'O', 'O'),
#   ('Jarl', 'O', 'O'),
#   ('ernannt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('In', 'O', 'O'),
#   ('manchen', 'O', 'O'),
#   ('Gebieten', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Beispiel', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Dachau', 'B-LOC', 'O'),
#   ('Süd', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('gibt', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('nur', 'O', 'O'),
#   ('wenig', 'O', 'O'),
#   ('Möglichkeiten', 'O', 'O'),
#   ('Waren', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('alltäglichen', 'O', 'O'),
#   ('Gebrauch', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('erwerben', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Bei', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Privaten', 'O', 'O'),
#   ('Krankenversicherern', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('DKV', 'B-ORG', 'O'),
#   ('einer', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Vorreiter', 'O', 'O'),
#   ('solcher', 'O', 'O'),
#   ('Zusatzangebote', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Nach', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Abitur', 'O', 'O'),
#   ('besuchte', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Musicalschule', 'O', 'O'),
#   ('Vitztum-Durukan', 'B-ORG', 'O'),
#   ('in', 'O', 'O'),
#   ('Hannover', 'B-LOC', 'O'),
#   ('und', 'O', 'O'),
#   ('ließ', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Fächern', 'O', 'O'),
#   ('Schauspiel', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Tanz', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Gesang', 'O', 'O'),
#   ('ausbilden', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('außerdem', 'O', 'O'),
#   ('nahm', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('privaten', 'O', 'O'),
#   ('Gesangsunterricht', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Nach', 'O', 'O'),
#   ('Ansicht', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Kritikern', 'O', 'O'),
#   ('lässt', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('diesen', 'O', 'O'),
#   ('Forderungen', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Befürwortung', 'O', 'O'),
#   ('einer', 'O', 'O'),
#   ('erneuten', 'O', 'O'),
#   ('Angliederung', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('heute', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('tschechischen', 'B-LOCderiv', 'O'),
#   ('Staat', 'O', 'O'),
#   ('gehörenden', 'O', 'O'),
#   ('Sudetenlandes', 'B-LOC', 'O'),
#   ('an', 'O', 'O'),
#   ('Deutschland', 'B-LOC', 'O'),
#   ('erkennen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Liberalismus', 'O', 'O'),
#   ('samt', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('kapitalistischen', 'O', 'O'),
#   ('Wirtschaftssystem', 'O', 'O'),
#   ('schien', 'O', 'O'),
#   ('abgewirtschaftet', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('haben', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Für', 'O', 'O'),
#   ('Hauser', 'B-PER', 'O'),
#   ('kann', 'O', 'O'),
#   ('ins', 'O', 'O'),
#   ('Feld', 'O', 'O'),
#   ('geführt', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('bei', 'O', 'O'),
#   ('seinen', 'O', 'O'),
#   ('Grabungen', 'O', 'O'),
#   ('bereits', 'O', 'O'),
#   ('Einmessungen', 'O', 'O'),
#   ('durch', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('Geodäten', 'O', 'O'),
#   ('durchführen', 'O', 'O'),
#   ('ließ', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Eintritt', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('frei', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Veranstaltung', 'O', 'O'),
#   ('beginnt', 'O', 'O'),
#   ('um', 'O', 'O'),
#   ('19', 'O', 'O'),
#   ('Uhr', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Direkt', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Spiel', 'O', 'O'),
#   ('hieß', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('aus', 'O', 'O'),
#   ('Vorstandskreisen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('man', 'O', 'O'),
#   ('trotz', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('erneuten', 'O', 'O'),
#   ('Schlappe', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('vorzeitigen', 'O', 'O'),
#   ('Rauswurf', 'O', 'O'),
#   ('denke', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Fast', 'O', 'O'),
#   ('durchgehend', 'O', 'O'),
#   ('finden', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Klingenberg', 'B-LOC', 'O'),
#   ('traditionellen', 'O', 'O'),
#   ('Häckerwirtschaften', 'O', 'O'),
#   ('statt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('wobei', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('mehrere', 'O', 'O'),
#   ('Winzer', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('regelmäßigen', 'O', 'O'),
#   ('Abständen', 'O', 'O'),
#   ('abwechseln', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Am', 'O', 'O'),
#   ('Samstagnachmittag', 'O', 'O'),
#   ('findet', 'O', 'O'),
#   ('noch', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Begegnung', 'O', 'O'),
#   ('Budel', 'B-LOC', 'O'),
#   ('gegen', 'O', 'O'),
#   ('Philippsburg', 'B-LOC', 'O'),
#   ('statt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('Album', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('2000', 'O', 'O'),
#   ('über', 'O', 'O'),
#   ('Relapse', 'B-ORG', 'O'),
#   ('Records', 'I-ORG', 'O'),
#   ('wiederveröffentlicht', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('ersten', 'O', 'O'),
#   ('Mal', 'O', 'O'),
#   ('einem', 'O', 'O'),
#   ('breiten', 'O', 'O'),
#   ('Publikum', 'O', 'O'),
#   ('vorgestellt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Im', 'O', 'O'),
#   ('Nordosten', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('Geichlingen', 'B-LOC', 'O'),
#   ('und', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Osten', 'O', 'O'),
#   ('Hüttingen', 'B-LOC', 'O'),
#   ('bei', 'O', 'O'),
#   ('Lahr', 'B-LOC', 'O'),
#   ('jeweils', 'O', 'O'),
#   ('etwa', 'O', 'O'),
#   ('3km', 'O', 'O'),
#   ('entfernt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Schon', 'O', 'O'),
#   ('beim', 'O', 'O'),
#   ('Wort', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Ode', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('glauben', 'O', 'O'),
#   ('Nachgeborene', 'O', 'O'),
#   ('bestenfalls', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('handele', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('um', 'O', 'O'),
#   ('irgendwas', 'O', 'O'),
#   ('zwischen', 'O', 'O'),
#   ('Mode', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('bedauernswerten', 'O', 'O'),
#   ('Ort', 'O', 'O'),
#   ('Frankfurt', 'B-LOC', 'O'),
#   ('an', 'I-LOC', 'O'),
#   ('der', 'I-LOC', 'O'),
#   ('Oder', 'I-LOC', 'B-LOC'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Kirchen-', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Klostereinrichtung', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('verkauft', 'O', 'O'),
#   (';', 'O', 'O'),
#   ('einzelne', 'O', 'O'),
#   ('Gegenstände', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('noch', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Kirchen', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Umgebung', 'O', 'O'),
#   ('erhalten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('25jährige', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('am', 'O', 'O'),
#   ('Sonnabend', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Braunschweig', 'B-LOC', 'O'),
#   ('im', 'O', 'O'),
#   ('Rahmen', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Supermittelgewichts-WM', 'O', 'O'),
#   ('Mario', 'B-PER', 'O'),
#   ('Veit', 'I-PER', 'O'),
#   ('(', 'O', 'O'),
#   ('Universum', 'B-ORG', 'O'),
#   (')', 'O', 'O'),
#   ('-', 'O', 'O'),
#   ('Joe', 'B-PER', 'O'),
#   ('Calzaghe', 'I-PER', 'O'),
#   ('(', 'O', 'O'),
#   ('Wales', 'B-LOC', 'O'),
#   (')', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('zweiten', 'O', 'O'),
#   ('Hauptkampf', 'O', 'O'),
#   ('bestreiten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Endrunde', 'O', 'O'),
#   ('teilnehmenden', 'O', 'O'),
#   ('Verbände', 'O', 'O'),
#   ('erhalten', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('jedes', 'O', 'O'),
#   ('Spiel', 'O', 'O'),
#   ('ihres', 'O', 'O'),
#   ('Teams', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Durchschnitt', 'O', 'O'),
#   ('19', 'O', 'O'),
#   ('Prozent', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Kartenkontingentes', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Booles', 'B-PER', 'O'),
#   ('System', 'O', 'O'),
#   ('verwendet', 'O', 'O'),
#   ('Großbuchstaben', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('Begriffe', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Zeichen', 'O', 'O'),
#   ('0', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Null', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('leeren', 'O', 'O'),
#   ('Begriff', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('unter', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('nichts', 'O', 'O'),
#   ('fällt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Zeichen', 'O', 'O'),
#   ('1', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Eins', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('universellen', 'O', 'O'),
#   ('Begriff', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('unter', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('alles', 'O', 'O'),
#   ('fällt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Ball', 'O', 'O'),
#   ('rollt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('warum', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('welche', 'O', 'O'),
#   ('Richtng', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('immer', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('"', 'O', 'O'),
#   ('Jetzt', 'O', 'O'),
#   ('sollte', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('FDP', 'B-ORG', 'O'),
#   ('zu', 'O', 'O'),
#   ('ihrem', 'O', 'O'),
#   ('Wort', 'O', 'O'),
#   ('stehen', 'O', 'O'),
#   ('"', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('sagte', 'O', 'O'),
#   ('Dobrindt', 'B-PER', 'O'),
#   ('der', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Welt', 'B-ORG', 'O'),
#   ('am', 'I-ORG', 'O'),
#   ('Sonntag', 'I-ORG', 'O'),
#   ('"', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('Ostersonntagsprogramm', 'O', 'O'),
#   ('verhalf', 'O', 'O'),
#   ('RTL', 'B-ORG', 'O'),
#   ('zum', 'O', 'O'),
#   ('Tagessieg', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Dazu', 'O', 'O'),
#   ('gehört', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('erleichterter', 'O', 'O'),
#   ('Informationsaustausch', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('gemeinsame', 'O', 'O'),
#   ('Streifen', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Binnengrenzraum', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Möglichkeiten', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('grenzüberschreitenden', 'O', 'O'),
#   ('Observation', 'O', 'O'),
#   ('oder', 'O', 'O'),
#   ('Verfolgung', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Straftätern', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Nacheile', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Dann', 'O', 'O'),
#   ('erklärt', 'O', 'O'),
#   ('Haas', 'B-PER', 'O'),
#   (',', 'O', 'O'),
#   ('was', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('alles', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Schränken', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Rettungswagens', 'O', 'O'),
#   ('befindet', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('was', 'O', 'O'),
#   ('man', 'O', 'O'),
#   ('damit', 'O', 'O'),
#   ('machen', 'O', 'O'),
#   ('kann', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Journalisten', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Anhänger', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Klubs', 'O', 'O'),
#   ('gliederten', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Vereinsnamen', 'O', 'O'),
#   ('jedoch', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Wiener', 'B-ORG', 'B-LOCderiv'),
#   ('Association', 'I-ORG', 'O'),
#   ('Footballclub', 'I-ORG', 'O'),
#   ('"', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('woraus', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('später', 'O', 'O'),
#   ('üblich', 'O', 'O'),
#   ('gewordene', 'O', 'O'),
#   ('Bezeichnung', 'O', 'O'),
#   ('WAF', 'B-ORG', 'O'),
#   ('hervorging', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Dabei', 'O', 'O'),
#   ('sollen', 'O', 'O'),
#   ('vor', 'O', 'O'),
#   ('allem', 'O', 'O'),
#   ('aktuelle', 'O', 'O'),
#   ('Forschungen', 'O', 'O'),
#   ('berücksichtigt', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('größte', 'O', 'O'),
#   ('Fund', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('sogenannte', 'O', 'O'),
#   ('Goldmaske', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Agamemnon', 'B-PER', 'O'),
#   ('aus', 'O', 'O'),
#   ('Mykene', 'B-LOC', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('heutigen', 'O', 'O'),
#   ('Erkenntnissen', 'O', 'O'),
#   ('allerdings', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('Agamemnon', 'B-PER', 'O'),
#   ('zugesprochen', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('kann', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('da', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('aus', 'O', 'O'),
#   ('einer', 'O', 'O'),
#   ('um', 'O', 'O'),
#   ('etwa', 'O', 'O'),
#   ('300', 'O', 'O'),
#   ('Jahre', 'O', 'O'),
#   ('früheren', 'O', 'O'),
#   ('Ära', 'O', 'O'),
#   ('stammt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Um', 'O', 'O'),
#   ('19:00', 'O', 'O'),
#   ('Uhr', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('Bundesland', 'O', 'O'),
#   ('heute', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Nachrichten', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Bundesländer', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('neun', 'O', 'O'),
#   ('regionale', 'O', 'O'),
#   ('Fensterprogramme', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('jedes', 'O', 'O'),
#   ('Bundesland', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('Sendung', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Er', 'O', 'O'),
#   ('liebt', 'O', 'O'),
#   ('alles', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('was', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('Kunst', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('tun', 'O', 'O'),
#   ('hat', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Selbst', 'O', 'O'),
#   ('wenn', 'O', 'O'),
#   ('sein', 'O', 'O'),
#   ('Leben', 'O', 'O'),
#   ('unstet', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('wenig', 'O', 'O'),
#   ('ortsgebunden', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('so', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('doch', 'O', 'O'),
#   ('alles', 'O', 'O'),
#   ('andere', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('ungeordnet', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('zügellos', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Karlsruhe', 'B-LOC', 'O'),
#   ('-', 'O', 'O'),
#   ('Das', 'O', 'O'),
#   ('Bundesverfassungsgericht', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('sein', 'O', 'O'),
#   ('Urteil', 'O', 'O'),
#   ('zur', 'O', 'O'),
#   ('vorgezogenen', 'O', 'O'),
#   ('Bundestagswahl', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Woche', 'O', 'O'),
#   ('ab', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('22.', 'O', 'O'),
#   ('August', 'O', 'O'),
#   ('verkünden', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('schmal-lanzettlichen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('siebennervigen', 'O', 'O'),
#   ('Deckspelzen', 'O', 'O'),
#   ('überdecken', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('erreichen', 'O', 'O'),
#   ('8', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('15', 'O', 'O'),
#   ('Millimeter', 'O', 'O'),
#   ('Länge', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('zugespitzt', 'O', 'O'),
#   ('oder', 'O', 'O'),
#   ('leicht', 'O', 'O'),
#   ('zweizähnig', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Spitze', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Rücken', 'O', 'O'),
#   ('gekielt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('Ziel', 'O', 'O'),
#   ('sei', 'O', 'O'),
#   ('bescheiden', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('aber', 'O', 'O'),
#   ('realistisch', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('schreibt', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Mailänder', 'B-LOCderiv', 'O'),
#   ('Tageszeitung', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Corriere', 'B-ORG', 'O'),
#   ('della', 'I-ORG', 'O'),
#   ('Sera', 'I-ORG', 'O'),
#   ('"', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Beide', 'O', 'O'),
#   ('Fahrgestelle', 'O', 'O'),
#   ('waren', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('nur', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('Mechanik', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Motorverkleidung', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Chassis', 'O', 'O'),
#   ('&', 'O', 'O'),
#   ('Cowl', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('erhältlich', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ich', 'O', 'O'),
#   ('denke', 'O', 'O'),
#   ('keine', 'O', 'O'),
#   ('Meinung', 'O', 'O'),
#   ('eines', 'O', 'O'),
#   ('Gegenübers', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Lachen', 'O', 'O'),
#   ('–', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('verbietet', 'O', 'O'),
#   ('schon', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Anstand', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Achtung', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Motor', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('wieder', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Heck', 'O', 'O'),
#   ('angeordnet', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('obwohl', 'O', 'O'),
#   ('dieses', 'O', 'O'),
#   ('Konzept', 'O', 'O'),
#   ('bereits', 'O', 'O'),
#   ('beim', 'O', 'O'),
#   ('Erscheinen', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('T3', 'B-OTH', 'O'),
#   ('als', 'O', 'O'),
#   ('überholt', 'O', 'O'),
#   ('galt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('weil', 'O', 'O'),
#   ('so', 'O', 'O'),
#   ('immer', 'O', 'O'),
#   ('noch', 'O', 'O'),
#   ('keine', 'O', 'O'),
#   ('durchgehende', 'O', 'O'),
#   ('Ladefläche', 'O', 'O'),
#   ('zur', 'O', 'O'),
#   ('Verfügung', 'O', 'O'),
#   ('gestellt', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('konnte', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Erst', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('Brad', 'B-PER', 'O'),
#   ('Buetow', 'I-PER', 'O'),
#   (',', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('schon', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('letzten', 'O', 'O'),
#   ('beiden', 'O', 'O'),
#   ('Jahre', 'O', 'O'),
#   ('am', 'O', 'O'),
#   ('College', 'O', 'O'),
#   ('assistiert', 'O', 'O'),
#   ('hatte', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Cheftrainerposten', 'O', 'O'),
#   ('bei', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Quad', 'B-ORG', 'O'),
#   ('City', 'I-ORG', 'O'),
#   ('Mallards', 'I-ORG', 'O'),
#   ('aus', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Colonial', 'B-ORG', 'O'),
#   ('Hockey', 'I-ORG', 'O'),
#   ('League', 'I-ORG', 'O'),
#   ('übernahm', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('holte', 'O', 'O'),
#   ('ihn', 'O', 'O'),
#   ('dieser', 'O', 'O'),
#   ('erneut', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('seinen', 'O', 'O'),
#   ('Assistenten', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Über', 'O', 'O'),
#   ('20', 'O', 'O'),
#   ('Jahre', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Produktion', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Grundlinie', 'O', 'O'),
#   ('beibehalten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Lkw', 'O', 'O'),
#   ('geriet', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('rechts', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Fahrbahn', 'O', 'O'),
#   ('ab', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('kollidierte', 'O', 'O'),
#   ('dort', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('mehreren', 'O', 'O'),
#   ('am', 'O', 'O'),
#   ('Fahrbahnrand', 'O', 'O'),
#   ('abgestellten', 'O', 'O'),
#   ('Fahrzeugen', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('kam', 'O', 'O'),
#   ('schließlich', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('einer', 'O', 'O'),
#   ('Hauswand', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Stehen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Trotzdem', 'O', 'O'),
#   ('kam', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('zeitweise', 'O', 'O'),
#   ('gewalttätigen', 'O', 'O'),
#   ('Ausschreitungen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Wir', 'O', 'O'),
#   ('haben', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('ökumenischen', 'O', 'O'),
#   ('Jugendgottesdienst', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Osnabrücker', 'B-LOCderiv', 'O'),
#   ('Bischof', 'O', 'O'),
#   ('Franz-Josef', 'B-PER', 'O'),
#   ('Bode', 'I-PER', 'O'),
#   ('und', 'O', 'O'),
#   ('mir', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Technische', 'O', 'O'),
#   ('Rahmenbedingungen', 'O', 'O'),
#   ('Aus', 'O', 'O'),
#   ('technischer', 'O', 'O'),
#   ('Sicht', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('derzeit', 'O', 'O'),
#   ('Chipkarten', 'O', 'O'),
#   ('bzw.', 'O', 'O'),
#   ('sogenannte', 'O', 'O'),
#   ('Smartcards', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Mittel', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Wahl', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('um', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Sicherheitsanforderungen', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('solch', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('Modell', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('genügen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Dieses', 'O', 'O'),
#   ('Zitat', 'O', 'O'),
#   ('stammt', 'O', 'O'),
#   ('aus', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('ersten', 'O', 'O'),
#   ('Strophe', 'O', 'O'),
#   ('eines', 'O', 'O'),
#   ('Gedichts', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('August', 'B-PER', 'O'),
#   ('Schnelzer', 'I-PER', 'O'),
#   (':', 'O', 'O'),
#   (':', 'O', 'O'),
#   ('„', 'O', 'O'),
#   ("''", 'O', 'O'),
#   ('Gold', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Silber', 'O', 'O'),
#   ('preis', 'O', 'O'),
#   ('ich', 'O', 'O'),
#   ('sehr', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Könnt', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('wohl', 'O', 'O'),
#   ('brauchen', 'O', 'O'),
#   (';', 'O', 'O'),
#   ('Hätt', 'O', 'O'),
#   ('ich', 'O', 'O'),
#   ('nur', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('ganzes', 'O', 'O'),
#   ('Meer', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Mich', 'O', 'O'),
#   ('hineinzutauchen', 'O', 'O'),
#   ('!', 'O', 'O'),
#   ("'", 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Resonanz', 'O', 'O'),
#   ('habe', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Erwartungen', 'O', 'O'),
#   ('übertroffen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('sagten', 'O', 'O'),
#   ('Stefani', 'B-PER', 'O'),
#   ('Korn', 'I-PER', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Seiten', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Wirtschaftsministeriums', 'O', 'O'),
#   ('schon', 'O', 'O'),
#   ('mehrere', 'O', 'O'),
#   ('derartige', 'O', 'O'),
#   ('Initiativen', 'O', 'O'),
#   ('begleitet', 'O', 'O'),
#   ('hat', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Felicitas', 'B-PER', 'O'),
#   ('Steck', 'I-PER', 'O'),
#   ('.', 'O', 'O')],
#  [('Fast', 'O', 'O'),
#   ('schon', 'O', 'O'),
#   ('abgeschrieben', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('kämpfte', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('Oliver', 'B-PER', 'O'),
#   ('Herber', 'I-PER', 'O'),
#   ('2006', 'O', 'O'),
#   ('wieder', 'O', 'O'),
#   ('ins', 'O', 'O'),
#   ('Aufgebot', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('SGD', 'B-ORG', 'O'),
#   ('zurück', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('bestritt', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Folge', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('wieder', 'O', 'O'),
#   ('Spiele', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('Dynamo', 'B-ORG', 'O'),
#   ('Dresden', 'I-ORG', 'B-LOC'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Jahre', 'O', 'O'),
#   ('zwischen', 'O', 'O'),
#   ('1738', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('1758', 'O', 'O'),
#   ('stellten', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Höhepunkt', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Schaffens', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('David', 'B-PER', 'O'),
#   ('Herrliberger', 'I-PER', 'O'),
#   ('dar', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Alle', 'O', 'O'),
#   ('versuchen', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('schweren', 'O', 'O'),
#   ('Zeiten', 'O', 'O'),
#   ('zusammen', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('rücken', 'O', 'O'),
#   ('aber', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Balkan', 'B-LOC', 'O'),
#   ('macht', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('genau', 'O', 'O'),
#   ('anders', 'O', 'O'),
#   ('herum', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Viele', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('vor', 'O', 'O'),
#   ('allem', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('vorige', 'O', 'O'),
#   ('Generation', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('finden', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Vorgaben', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Behörden', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('kompliziert', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Vielleicht', 'O', 'O'),
#   ('schenken', 'O', 'O'),
#   ('seine', 'O', 'O'),
#   ('Schützlinge', 'O', 'O'),
#   ('ihm', 'O', 'O'),
#   ('ja', 'O', 'O'),
#   ('nachträglich', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Wieder-)Aufstieg', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Feldhockey-Bundesliga', 'B-ORG', 'O'),
#   ('zum', 'O', 'O'),
#   ('Geburtstag', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Seine', 'O', 'O'),
#   ('Kirchentheorie', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('dabei', 'O', 'O'),
#   ('funktional', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('wesentlichen', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('Wertevermittlung', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Lebensbegleitung', 'O', 'O'),
#   ('ausgerichtet', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Nochmals', 'O', 'O'),
#   ('erwähnt', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('sollen', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Kirchenglocken', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('Geschäftsjahr', 'O', 'O'),
#   ('2009', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('insbesondere', 'O', 'O'),
#   ('durch', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('florierende', 'O', 'O'),
#   ('Geschäft', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('i', 'B-ORG', 'O'),
#   (':FAO', 'I-ORG', 'O'),
#   ('Group', 'I-ORG', 'O'),
#   ('GmbH', 'I-ORG', 'O'),
#   ('geprägt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Software-as-a-Service', 'O', 'O'),
#   ('Software', 'O', 'O'),
#   ('cytric', 'B-OTH', 'O'),
#   ('das', 'O', 'O'),
#   ('Planen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Buchen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Abrechnen', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Management', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Geschäftsreisen', 'O', 'O'),
#   ('kostensparend', 'O', 'O'),
#   ('ermöglicht', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ein', 'O', 'O'),
#   ('paar', 'O', 'O'),
#   ('T-Shirts', 'O', 'O'),
#   ('mehr', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('so', 'O', 'O'),
#   ('flachst', 'O', 'O'),
#   ('er', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('können', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Rückweg', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('Flieger', 'O', 'O'),
#   ('leisten', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('Geiger', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Dirigent', 'O', 'O'),
#   ('Yehudi', 'B-PER', 'O'),
#   ('Menuhin', 'I-PER', 'O'),
#   ('(', 'O', 'O'),
#   ('1916-1999', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('hatte', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('gemeinnützige', 'O', 'O'),
#   ('Stiftung', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('unter', 'O', 'O'),
#   ('anderem', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('musikalische', 'O', 'O'),
#   ('Förderung', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Kindern', 'O', 'O'),
#   ('einsetzt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('kurz', 'O', 'O'),
#   ('vor', 'O', 'O'),
#   ('seinem', 'O', 'O'),
#   ('Tod', 'O', 'O'),
#   ('gegründet', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Sie', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('gespielt', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Hamburger', 'B-LOCderiv', 'O'),
#   ('Pianisten', 'O', 'O'),
#   ('Gudula', 'B-PER', 'O'),
#   ('Schreiber', 'I-PER', 'O'),
#   ('und', 'O', 'O'),
#   ('Reiner', 'B-PER', 'O'),
#   ('Schelski', 'I-PER', 'O'),
#   ('sowie', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Christine', 'B-PER', 'O'),
#   ('K.', 'I-PER', 'O'),
#   ('Brückner', 'I-PER', 'O'),
#   ('.', 'O', 'O')],
#  [('"', 'O', 'O'),
#   ('Ich', 'O', 'O'),
#   ('konnte', 'O', 'O'),
#   ('nichts', 'O', 'O'),
#   ('machen', 'O', 'O'),
#   ('"', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('klagt', 'O', 'O'),
#   ('Dumbreck', 'B-PER', 'O'),
#   ('.', 'O', 'O')],
#  [('Unter', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Unterwegs', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('frischen', 'O', 'O'),
#   ('Luft', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('gibt', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('Vorschläge', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('Radtouren', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Wanderungen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('Besuche', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Wildparks', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Abenteuerspielplätzen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('fürs', 'O', 'O'),
#   ('Rodeln', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Eislaufen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('zeigt', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Kernproblem', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('wie', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('Benn', 'B-PER', 'O'),
#   ('empfindet', 'O', 'O'),
#   (':', 'O', 'O'),
#   ('Wo', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Ort', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Literatur', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('einer', 'O', 'O'),
#   ('Kultur', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('gesamte', 'O', 'O'),
#   ('Definitionsmacht', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Dichter', 'O', 'O'),
#   ('und', 'O', 'O'),
# ...
#   ('aus', 'O', 'O'),
#   ('McCartneys', 'B-PER', 'O'),
#   ('Ohr', 'O', 'O'),
#   ('herausstreckt', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('so', 'O', 'O'),
#   ('aussieht', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('als', 'O', 'O'),
#   ('ob', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('angestrengt', 'O', 'O'),
#   ('versucht', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('etwas', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('hören', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Mit', 'O', 'O'),
#   ('seinem', 'O', 'O'),
#   ('Freund', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Kollegen', 'O', 'O'),
#   ('Otto', 'B-PER', 'O'),
#   ('Kitzinger', 'I-PER', 'O'),
#   ('brachte', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Zeitschrift', 'O', 'O'),
#   ('„', 'O', 'O'),
#   ('Der', 'B-ORG', 'O'),
#   ('Einzelhandelsdienst', 'I-ORG', 'O'),
#   ('“', 'O', 'O'),
#   ('heraus', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Im', 'O', 'O'),
#   ('palästinensischen', 'B-LOCderiv', 'O'),
#   ('Lager', 'O', 'O'),
#   ('fehlt', 'O', 'O'),
#   ('aufgrund', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Spaltung', 'O', 'O'),
#   ('zwischen', 'O', 'O'),
#   ('Fatah', 'B-ORG', 'O'),
#   ('und', 'O', 'O'),
#   ('Hamas', 'B-ORG', 'O'),
#   ('weiterhin', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('breit', 'O', 'O'),
#   ('abgestützter', 'O', 'O'),
#   ('Verhandlungspartner', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('In', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Landeshauptstadt', 'O', 'O'),
#   ('Salzburg', 'B-LOC', 'O'),
#   ('leben', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('Anfang', 'O', 'O'),
#   ('2009', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('149.108', 'O', 'O'),
#   ('Einwohner', 'O', 'O'),
#   (';', 'O', 'O'),
#   ('sie', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('damit', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('viertgrößte', 'O', 'O'),
#   ('Stadt', 'O', 'O'),
#   ('Österreichs', 'B-LOC', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Belgier', 'B-LOCderiv', 'O'),
#   ('hatten', 'O', 'O'),
#   ('25,1', 'O', 'O'),
#   ('Prozent', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Aktien', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Tausch', 'O', 'O'),
#   ('gegen', 'O', 'O'),
#   ('ihre', 'O', 'O'),
#   ('Beteiligung', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('RTL', 'B-ORG', 'O'),
#   ('erhalten', 'O', 'O'),
#   ('-', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Recht', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('einer', 'O', 'O'),
#   ('Wartezeit', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Börse', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('gehen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Seit', 'O', 'O'),
#   ('2005', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Titel', 'O', 'O'),
#   ('regelmäßig', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Abspann', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Upps', 'B-OTH', 'O'),
#   ('!', 'I-OTH', 'O')],
#  [('Ruine', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Semperoper', 'B-LOC', 'O'),
#   ('Stehengebliebenes', 'O', 'O'),
#   ('Treppenhaus', 'O', 'O'),
#   ('1945', 'O', 'O'),
#   ('Der', 'O', 'O'),
#   ('Straßenverkehr', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('13.', 'O', 'O'),
#   ('Februar', 'O', 'O'),
#   ('zunächst', 'O', 'O'),
#   ('vollständig', 'O', 'O'),
#   ('blockiert', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Bei', 'O', 'O'),
#   ('sequentiellen', 'O', 'O'),
#   ('Aufgaben', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('CPU', 'O', 'O'),
#   ('daher', 'O', 'O'),
#   ('schneller', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Jedoch', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('Grundkenntnisse', 'O', 'O'),
#   ('beim', 'O', 'O'),
#   ('Begleiten', 'O', 'O'),
#   ('empfehlenswert', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Sie', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('Lügner', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Heuchler', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('1556', 'O', 'O'),
#   ('war', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Provinz', 'O', 'O'),
#   ('Shanxi', 'B-LOC', 'O'),
#   ('durch', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('schwere', 'O', 'O'),
#   ('Erdbeben', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Shaanxi', 'B-LOC', 'O'),
#   ('1556', 'O', 'O'),
#   ('betroffen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('IOC', 'B-ORG', 'O'),
#   ('Executive', 'O', 'O'),
#   ('Board', 'O', 'O'),
#   ('trifft', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('vom', 'O', 'O'),
#   ('4.', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('6.', 'O', 'O'),
#   ('Juni', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Athen', 'B-LOC', 'O'),
#   ('.', 'O', 'O')],
#  [('Bei', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Gesamtzuschauern', 'O', 'O'),
#   ('sah', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Mission', 'B-OTH', 'O'),
#   (':', 'I-OTH', 'O'),
#   ('Impossible', 'I-OTH', 'O'),
#   ('III', 'I-OTH', 'O'),
#   ('"', 'O', 'O'),
#   ('bei', 'O', 'O'),
#   ('ProSieben', 'B-ORG', 'O'),
#   ('garnicht', 'O', 'O'),
#   ('so', 'O', 'O'),
#   ('schlecht', 'O', 'O'),
#   ('aus', 'O', 'O'),
#   (':', 'O', 'O'),
#   ('2,72', 'O', 'O'),
#   ('Millionen', 'O', 'O'),
#   ('Menschen', 'O', 'O'),
#   ('schalteten', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('sorgten', 'O', 'O'),
#   ('für', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('guten', 'O', 'O'),
#   ('Marktanteil', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('8,4', 'O', 'O'),
#   ('Prozent', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ausgediente', 'O', 'O'),
#   ('Elektrogeräte', 'O', 'O'),
#   ('dürfen', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('heute', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('mehr', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('graue', 'O', 'O'),
#   ('Restmülltonne', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('1731', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Kirche', 'O', 'O'),
#   ('im', 'O', 'O'),
#   ('Barockstil', 'B-OTHpart', 'O'),
#   ('umgebaut', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('erhielt', 'O', 'O'),
#   ('1805', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Erhebung', 'O', 'O'),
#   ('zum', 'O', 'O'),
#   ('Dekanat', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Inzwischen', 'O', 'O'),
#   ('wurden', 'O', 'O'),
#   ('mehrere', 'O', 'O'),
#   ('Unterarten', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Puma', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Anhang', 'O', 'O'),
#   ('I', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Washingtoner', 'B-OTH', 'B-LOCderiv'),
#   ('Artenschutzübereinkommens', 'I-OTH', 'O'),
#   ('aufgenommen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('übrigen', 'O', 'O'),
#   ('Unterarten', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Anhang', 'O', 'O'),
#   ('II.', 'O', 'O')],
#  [('Als', 'O', 'O'),
#   ('Abwurfmunition', 'O', 'O'),
#   ('wurden', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('2.722', 'O', 'O'),
#   ('kg', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('6.000', 'O', 'O'),
#   ('pounds', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('jedoch', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('Aero', 'B-OTH', 'O'),
#   ('123', 'I-OTH', 'O'),
#   ('–', 'O', 'O'),
#   ('S.', 'O', 'O'),
#   ('3488', 'O', 'O'),
#   ('sollten', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('1814', 'O', 'O'),
#   ('kg', 'O', 'O'),
#   ('(', 'O', 'O'),
#   ('4.000', 'O', 'O'),
#   ('Pounds', 'O', 'O'),
#   (')', 'O', 'O'),
#   ('gewesen', 'O', 'O'),
#   ('sein', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Der', 'O', 'O'),
#   ('gläserne', 'O', 'O'),
#   ('Sarg', 'O', 'O'),
#   ('ruht', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('einem', 'O', 'O'),
#   ('schwarz', 'O', 'O'),
#   ('gebeizten', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('mit', 'O', 'O'),
#   ('Silber', 'O', 'O'),
#   ('beschlagenen', 'O', 'O'),
#   ('Sockel', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ilja', 'B-PER', 'O'),
#   ('Ehrenburg', 'I-PER', 'O'),
#   ('selbst', 'O', 'O'),
#   ('entdeckte', 'O', 'O'),
#   ('1944', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Minsk', 'B-LOC', 'O'),
#   ('eine', 'O', 'O'),
#   ('große', 'O', 'O'),
#   ('Zahl', 'O', 'O'),
#   ('aufeinander', 'O', 'O'),
#   ('geschichteter', 'O', 'O'),
#   ('verkohlter', 'O', 'O'),
#   ('Leichen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Dafür', 'O', 'O'),
#   ('investierte', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Telekom', 'B-ORG', 'O'),
#   ('in', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('Full-HD-Sendestudio', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Diese', 'O', 'O'),
#   ('soziale', 'O', 'O'),
#   ('Grundsicherung', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('grundsätzlich', 'O', 'O'),
#   ('durch', 'O', 'O'),
#   ('Beiträge', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Versicherten', 'O', 'O'),
#   ('finanziert', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Defizite', 'O', 'O'),
#   ('allerdings', 'O', 'O'),
#   ('durch', 'O', 'O'),
#   ('Steuergelder', 'O', 'O'),
#   ('ausgeglichen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Künftig', 'O', 'O'),
#   ('gibt', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('sonnabends', 'O', 'O'),
#   ('dort', 'O', 'O'),
#   ('Partys', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('außerdem', 'O', 'O'),
#   ('Konzerte', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('andere', 'O', 'O'),
#   ('Veranstaltungen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Nach', 'O', 'O'),
#   ('mehreren', 'O', 'O'),
#   ('niedrigen', 'O', 'O'),
#   ('Verwaltungsposten', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('Bo', 'B-PER', 'O'),
#   ('1993', 'O', 'O'),
#   ('Bürgermeister', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Hafenstadt', 'O', 'O'),
#   ('Dalian', 'B-LOC', 'O'),
#   ('-', 'O', 'O'),
#   ('wohl', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('letzte', 'O', 'O'),
#   ('Beförderung', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('seinem', 'O', 'O'),
#   ('Vater', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('verdanken', 'O', 'O'),
#   ('hatte', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Die', 'O', 'O'),
#   ('Auflegung', 'O', 'O'),
#   ('neuer', 'O', 'O'),
#   ('Fonds', 'O', 'O'),
#   ('wurde', 'O', 'O'),
#   ('bis', 'O', 'O'),
#   ('auf', 'O', 'O'),
#   ('weiteres', 'O', 'O'),
#   ('ausgesetzt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Banken', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('nahegelegt', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('keine', 'O', 'O'),
#   ('Investitionskredite', 'O', 'O'),
#   ('mehr', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('bewilligen', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('ganz', 'O', 'O'),
#   ('allgemein', 'O', 'O'),
#   ('ziehen', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('chinesischen', 'B-LOCderiv', 'O'),
#   ('Aufsichtsbehörden', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Bremse', 'O', 'O'),
#   ('an', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('was', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('weitere', 'O', 'O'),
#   ('Marktentwicklung', 'O', 'O'),
#   ('betrifft', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('So', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('gewährleistet', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('dass', 'O', 'O'),
#   ('keine', 'O', 'O'),
#   ('Normalspannungen', 'O', 'O'),
#   ('längs', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Profils', 'O', 'O'),
#   ('auftreten', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('obwohl', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('einzelne', 'O', 'O'),
#   ('Punkte', 'O', 'O'),
#   ('am', 'O', 'O'),
#   ('Profil', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('längsrichtung', 'O', 'O'),
#   ('verschieben', 'O', 'O'),
#   ('dürfen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Und', 'O', 'O'),
#   ('ergänzte', 'O', 'O'),
#   (':', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('Die', 'O', 'O'),
#   ('muss', 'O', 'O'),
#   ('man', 'O', 'O'),
#   ('mal', 'O', 'O'),
#   ('an', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Ehre', 'O', 'O'),
#   ('packen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Das', 'O', 'O'),
#   ('Tor', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Tages', 'O', 'O'),
#   ('gelang', 'O', 'O'),
#   ('Sebastian', 'B-PER', 'O'),
#   ('Kreibich', 'I-PER', 'O'),
#   ('auf', 'O', 'O'),
#   ('Vorarbeit', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Stefan', 'B-PER', 'O'),
#   ('Müller', 'I-PER', 'O'),
#   ('und', 'O', 'O'),
#   ('Waldemar', 'B-PER', 'O'),
#   ('Obendörfer', 'I-PER', 'O'),
#   ('..', 'O', 'O')],
#  [('Demnach', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Bund', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('diesem', 'O', 'O'),
#   ('Jahr', 'O', 'O'),
#   ('29', 'O', 'O'),
#   ('Milliarden', 'O', 'O'),
#   ('Euro', 'B-OTH', 'O'),
#   ('für', 'O', 'O'),
#   ('das', 'O', 'O'),
#   ('Arbeitslosengeld', 'B-OTH', 'O'),
#   ('II', 'I-OTH', 'O'),
#   ('ausgeben', 'O', 'O'),
#   ('-', 'O', 'O'),
#   ('fast', 'O', 'O'),
#   ('eine', 'O', 'O'),
#   ('Verdopplung', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('geplanten', 'O', 'O'),
#   ('Summe', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Schließlich', 'O', 'O'),
#   ('kann', 'O', 'O'),
#   ('er', 'O', 'O'),
#   ('sich', 'O', 'O'),
#   ('auch', 'O', 'O'),
#   ('nicht', 'O', 'O'),
#   ('mehr', 'O', 'O'),
#   ('über', 'O', 'O'),
#   ('den', 'O', 'O'),
#   ('Einmarsch', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('US-Amerikaner', 'B-LOCpart', 'O'),
#   ('freuen', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Labels', 'O', 'O'),
#   ('wie', 'O', 'O'),
#   ('2600', 'B-ORG', 'O'),
#   ('und', 'O', 'O'),
#   ('3com', 'B-ORG', 'O'),
#   ('dürfen', 'O', 'O'),
#   ('in', 'O', 'O'),
#   ('Hostnames', 'O', 'O'),
#   ('benutzt', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('-hi-', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('*hi*', 'O', 'O'),
#   ('sind', 'O', 'O'),
#   ('dagegen', 'O', 'O'),
#   ('ungültig', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Denn', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Forderung', 'O', 'O'),
#   ('nach', 'O', 'O'),
#   ('einem', 'O', 'O'),
#   ('weiteren', 'O', 'O'),
#   ('Abzug', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('ebenfalls', 'O', 'O'),
#   ('ohne', 'O', 'O'),
#   ('vorherige', 'O', 'O'),
#   ('Vereinbarungen', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Kompromisse', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('wird', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('palästinensischen', 'B-LOCderiv', 'O'),
#   ('Befürworter', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Oslo-Prozesses', 'B-LOCpart', 'O'),
#   ('zur', 'O', 'O'),
#   ('Änderung', 'O', 'O'),
#   ('ihrer', 'O', 'O'),
#   ('bisherigen', 'O', 'O'),
#   ('Haltung', 'O', 'O'),
#   ('bewegen', 'O', 'O'),
#   ('-', 'O', 'O'),
#   ('unnötigerweise', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Auch', 'O', 'O'),
#   ('bei', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Gesamtkapitalrendite', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('es', 'O', 'O'),
#   ('schwer', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('einen', 'O', 'O'),
#   ('Maßstab', 'O', 'O'),
#   ('festzulegen', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('da', 'O', 'O'),
#   ('diese', 'O', 'O'),
#   ('stark', 'O', 'O'),
#   ('branchenabhängig', 'O', 'O'),
#   ('ist', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('somit', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Branche', 'O', 'O'),
#   ('zu', 'O', 'O'),
#   ('Branche', 'O', 'O'),
#   ('enorme', 'O', 'O'),
#   ('Unterschiede', 'O', 'O'),
#   ('aufweisen', 'O', 'O'),
#   ('kann', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Bundeskanzlerin', 'O', 'O'),
#   ('Angela', 'B-PER', 'O'),
#   ('Merkel', 'I-PER', 'O'),
#   ('hat', 'O', 'O'),
#   ('bei', 'O', 'O'),
#   ('ihrer', 'O', 'O'),
#   ('Eröffnungsrede', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('Cebit', 'B-ORG', 'O'),
#   ('in', 'O', 'O'),
#   ('Hannover', 'B-LOC', 'O'),
#   ('die', 'O', 'O'),
#   ('Schaffung', 'O', 'O'),
#   ('eines', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('nationalen', 'O', 'O'),
#   ('IT-Gipfels', 'O', 'O'),
#   ('"', 'O', 'O'),
#   ('angekündigt', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Diese', 'O', 'O'),
#   ('müssten', 'O', 'O'),
#   ('aber', 'O', 'O'),
#   ('noch', 'O', 'O'),
#   ('untersucht', 'O', 'O'),
#   ('werden', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Ein', 'O', 'O'),
#   ('Ehrendekret', 'O', 'O'),
#   ('Sullas', 'B-PER', 'O'),
#   ('aus', 'O', 'O'),
#   ('dem', 'O', 'O'),
#   ('Jahre', 'O', 'O'),
#   ('80', 'O', 'O'),
#   ('v', 'O', 'O'),
#   ('.', 'O', 'O'),
#   ('Chr', 'B-PER', 'O'),
#   ('.', 'I-PER', 'O'),
#   ('erwähnt', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Opfer', 'O', 'O'),
#   ('und', 'O', 'O'),
#   ('Schäden', 'O', 'O'),
#   (',', 'O', 'O'),
#   ('welche', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Thasier', 'B-ORG', 'O'),
#   ('während', 'O', 'O'),
#   ('einer', 'O', 'O'),
#   ('Belagerung', 'O', 'O'),
#   ('durch', 'O', 'O'),
#   ('die', 'O', 'O'),
#   ('Armee', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Mithridates', 'B-PER', 'O'),
#   ('zu', 'O', 'O'),
#   ('erleiden', 'O', 'O'),
#   ('hatten', 'O', 'O'),
#   (';', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('Brief', 'O', 'O'),
#   ('des', 'O', 'O'),
#   ('Proconsuls', 'O', 'O'),
#   ('von', 'O', 'O'),
#   ('Makedonien', 'B-LOC', 'O'),
#   ('Cn', 'O', 'O'),
#   ('.', 'O', 'O')],
#  [('Unterdessen', 'O', 'O'),
#   ('entbrannte', 'O', 'O'),
#   ('ein', 'O', 'O'),
#   ('Machtkampf', 'O', 'O'),
#   ('zwischen', 'O', 'O'),
#   ('der', 'O', 'O'),
#   ('radikal-islamischen', 'O', 'O'),
#   ('Hamas', 'B-ORG', 'O'),
#   ('und', 'O', 'O'),
#   ('Palästinenserpräsident', 'B-LOCpart', 'O'),
#   ('Mahmud', 'B-PER', 'O'),
#   ('Abbas', 'I-PER', 'O'),
#   ('.', 'O', 'O')],
#  ...]

# %%
def word2features(sent, i):
    word = sent[i][0]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
sent2features(train_sents[0])
# Out:
# [{'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'sagte',
#   'BOS': True,
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': True,
#   'word.isupper()': False,
#   'word.lower()': 'schartau',
#   'word[-2:]': 'au',
#   'word[-3:]': 'tau'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'dem',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'schartau',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'sagte',
#   'word[-2:]': 'te',
#   'word[-3:]': 'gte'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': '"',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'sagte',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'dem',
#   'word[-2:]': 'em',
#   'word[-3:]': 'dem'},
#  {'+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'tagesspiegel',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'dem',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': '"',
#   'word[-2:]': '"',
#   'word[-3:]': '"'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': '"',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': '"',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': True,
#   'word.isupper()': False,
#   'word.lower()': 'tagesspiegel',
#   'word[-2:]': 'el',
#   'word[-3:]': 'gel'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'vom',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'tagesspiegel',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': '"',
#   'word[-2:]': '"',
#   'word[-3:]': '"'},
#  {'+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'freitag',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': '"',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'vom',
#   'word[-2:]': 'om',
#   'word[-3:]': 'vom'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'vom',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': True,
#   'word.isupper()': False,
#   'word.lower()': 'freitag',
#   'word[-2:]': 'ag',
#   'word[-3:]': 'tag'},
#  {'+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'fischer',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'freitag',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': ',',
#   'word[-2:]': ',',
#   'word[-3:]': ','},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'sei',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': ',',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': True,
#   'word.isupper()': False,
#   'word.lower()': 'fischer',
#   'word[-2:]': 'er',
#   'word[-3:]': 'her'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': '"',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'fischer',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'sei',
#   'word[-2:]': 'ei',
#   'word[-3:]': 'sei'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'in',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'sei',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': '"',
#   'word[-2:]': '"',
#   'word[-3:]': '"'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'einer',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': '"',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'in',
#   'word[-2:]': 'in',
#   'word[-3:]': 'in'},
#  {'+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'weise',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'in',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'einer',
#   'word[-2:]': 'er',
#   'word[-3:]': 'ner'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'aufgetreten',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'einer',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': True,
#   'word.isupper()': False,
#   'word.lower()': 'weise',
#   'word[-2:]': 'se',
#   'word[-3:]': 'ise'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': ',',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'weise',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'aufgetreten',
#   'word[-2:]': 'en',
#   'word[-3:]': 'ten'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'die',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'aufgetreten',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': ',',
#   'word[-2:]': ',',
#   'word[-3:]': ','},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'alles',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': ',',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'die',
#   'word[-2:]': 'ie',
#   'word[-3:]': 'die'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'andere',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'die',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'alles',
#   'word[-2:]': 'es',
#   'word[-3:]': 'les'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'als',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'alles',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'andere',
#   'word[-2:]': 're',
#   'word[-3:]': 'ere'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'überzeugend',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'andere',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'als',
#   'word[-2:]': 'ls',
#   'word[-3:]': 'als'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': 'war',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'als',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'überzeugend',
#   'word[-2:]': 'nd',
#   'word[-3:]': 'end'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': '"',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'überzeugend',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': 'war',
#   'word[-2:]': 'ar',
#   'word[-3:]': 'war'},
#  {'+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.lower()': '.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': 'war',
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': '"',
#   'word[-2:]': '"',
#   'word[-3:]': '"'},
#  {'-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.lower()': '"',
#   'EOS': True,
#   'bias': 1.0,
#   'word.isdigit()': False,
#   'word.istitle()': False,
#   'word.isupper()': False,
#   'word.lower()': '.',
#   'word[-2:]': '.',
#   'word[-3:]': '.'}]

# %%
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

X_train[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7194eeb1323d> in <module>()
#       1 X_train = [sent2features(s) for s in train_sents]
# ----> 2 y_train = [sent2labels(s) for s in train_sents]
#       3
#       4 X_test = [sent2features(s) for s in test_sents]
#       5 y_test = [sent2labels(s) for s in test_sents]
#
# <ipython-input-23-7194eeb1323d> in <listcomp>(.0)
#       1 X_train = [sent2features(s) for s in train_sents]
# ----> 2 y_train = [sent2labels(s) for s in train_sents]
#       3
#       4 X_test = [sent2features(s) for s in test_sents]
#       5 y_test = [sent2labels(s) for s in test_sents]
#
# <ipython-input-21-7d55a80d6c06> in sent2labels(sent)
#      40
#      41 def sent2labels(sent):
# ---> 42     return [label for token, label in sent]
#      43
#      44 def sent2tokens(sent):
#
# <ipython-input-21-7d55a80d6c06> in <listcomp>(.0)
#      40
#      41 def sent2labels(sent):
# ---> 42     return [label for token, label in sent]
#      43
#      44 def sent2tokens(sent):
#
# ValueError: too many values to unpack (expected 2)

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None,
#   all_possible_transitions=True, averaging=None, c=None, c1=0.1, c2=0.1,
#   calibration_candidates=None, calibration_eta=None,
#   calibration_max_trials=None, calibration_rate=None,
#   calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#   gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#   max_linesearch=None, min_freq=None, model_filename=None,
#   num_memories=None, pa_type=None, period=None, trainer_cls=None,
#   variance=None, verbose=False)

# %%
labels = list(crf.classes_)
labels.remove('O')
labels
# Out:
# ['B-LOC', 'B-ORG', 'B-PER', 'I-PER', 'B-MISC', 'I-ORG', 'I-LOC', 'I-MISC']

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels)
# Out:
# 0.7964686316443963

# %%
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#              precision    recall  f1-score   support
#
#       B-LOC      0.810     0.784     0.797      1084
#       I-LOC      0.690     0.637     0.662       325
#      B-MISC      0.731     0.569     0.640       339
#      I-MISC      0.699     0.589     0.639       557
#       B-ORG      0.807     0.832     0.820      1400
#       I-ORG      0.852     0.786     0.818      1104
#       B-PER      0.850     0.884     0.867       735
#       I-PER      0.893     0.943     0.917       634
#
# avg / total      0.809     0.787     0.796      6178
